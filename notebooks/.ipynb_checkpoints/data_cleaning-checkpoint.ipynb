# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/2018-2019/nacional/conjunto_de_datos/datos_mexico_2019.csv')
# Out:
# C:\Users\isaij\AppData\Local\Temp\ipykernel_35596\1072461261.py:1: DtypeWarning: Columns (0,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/2018-2019/nacional/conjunto_de_datos/datos_mexico_2019.csv')

# %%
df2 = pd.read_csv('../data/2018-2019/cdmx/hechos-de-transito-reportados-por-ssc-base-comparativa.csv')

# %% [markdown]
# # Datos nacionales

# %%
df.head()
# Out:
#    ID  EDO  MES  ANIO  MPIO  HORA  MINUTOS  DIA  DIASEMANA  URBANA  ...  \
# 0   8    1    1  2019     1     4        0    3          4       1  ...
# 1   9    1    1  2019     1     9       45    3          4       1  ...
# 2  10    1    1  2019     1    10       40    3          4       1  ...
# 3  11    1    1  2019     1    14       55    3          4       1  ...
# 4  12    1    1  2019     1    19        0    3          4       1  ...
#
#    OTROMUERTO  OTROHERIDO  TOTMUERTOS  TOTHERIDOS  CLASE  \
# 0           0           0           0           0      3
# 1           0           0           0           0      3
# 2           0           0           0           0      3
# 3           0           0           0           1      2
# 4           0           0           0           0      3
#
#                                       CALLE1                        CALLE2  \
# 0  BOULEVARD LICENCIADO ADOLFO RUÍZ CORTINES           CALLE PASEO DEL RÍO
# ...

# %%
df.tail()
# Out:
#          ID  EDO  MES  ANIO  MPIO  HORA  MINUTOS  DIA  DIASEMANA  URBANA  ...  \
# 180214  615   32   12  2019    56     1       39   25          3       1  ...
# 180215  616   32   12  2019    56     2       50   27          5       1  ...
# 180216  617   32   12  2019    56     9       37   27          5       1  ...
# 180217  619   32   12  2019    56    18       40   30          1       1  ...
# 180218  620   32   12  2019    56    15       45   31          2       1  ...
#
#         OTROMUERTO  OTROHERIDO  TOTMUERTOS  TOTHERIDOS  CLASE  \
# 180214           0           0           0           0      3
# 180215           0           0           0           0      3
# 180216           0           0           0           0      3
# 180217           0           0           0           2      2
# 180218           0           0           0           0      3
#
#                                                    CALLE1  \
# 180214                                    AVENIDA HIDALGO
# ...

# %%
df.shape
# Out:
# (180219, 49)

# %%
df.columns
# Out:
# Index(['ID', 'EDO', 'MES', 'ANIO', 'MPIO', 'HORA', 'MINUTOS', 'DIA',
#        'DIASEMANA', 'URBANA', 'SUBURBANA', 'TIPACCID', 'AUTOMOVIL', 'CAMPASAJ',
#        'MICROBUS', 'PASCAMION', 'OMNIBUS', 'TRANVIA', 'CAMIONETA', 'CAMION',
#        'TRACTOR', 'FERROCARRI', 'MOTOCICLET', 'BICICLETA', 'OTROVEHIC',
#        'CAUSAACCI', 'CAPAROD', 'SEXO', 'ALIENTO', 'CINTURON', 'EDAD',
#        'CONDMUERTO', 'CONDHERIDO', 'PASAMUERTO', 'PASAHERIDO', 'PEATMUERTO',
#        'PEATHERIDO', 'CICLMUERTO', 'CICLHERIDO', 'OTROMUERTO', 'OTROHERIDO',
#        'TOTMUERTOS', 'TOTHERIDOS', 'CLASE', 'CALLE1', 'CALLE2', 'CARRETERA',
#        'LONGITUD', 'LATITUD'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180219 entries, 0 to 180218
# Data columns (total 49 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          180219 non-null  object
#  1   EDO         180219 non-null  int64
#  2   MES         180219 non-null  int64
#  3   ANIO        180219 non-null  int64
#  4   MPIO        180219 non-null  int64
#  5   HORA        180219 non-null  int64
#  6   MINUTOS     180219 non-null  int64
#  7   DIA         180219 non-null  int64
#  8   DIASEMANA   180219 non-null  int64
#  9   URBANA      180219 non-null  int64
#  10  SUBURBANA   180219 non-null  int64
#  11  TIPACCID    180219 non-null  int64
#  12  AUTOMOVIL   180219 non-null  int64
#  13  CAMPASAJ    180219 non-null  int64
#  14  MICROBUS    180219 non-null  int64
#  15  PASCAMION   180219 non-null  int64
#  16  OMNIBUS     180219 non-null  int64
#  17  TRANVIA     180219 non-null  int64
#  18  CAMIONETA   180219 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  EDO            MES      ANIO           MPIO           HORA  \
# count  180219.000000  180219.000000  180219.0  180219.000000  180219.000000
# mean       16.373285       6.545558    2019.0      32.148148      12.750037
# std         7.100668       3.477758       0.0      30.395565       5.932928
# min         1.000000       1.000000    2019.0       1.000000       0.000000
# 25%        11.000000       3.000000    2019.0      14.000000       8.000000
# 50%        19.000000       7.000000    2019.0      26.000000      13.000000
# 75%        19.000000      10.000000    2019.0      39.000000      18.000000
# max        32.000000      12.000000    2019.0     193.000000      23.000000
#
#              MINUTOS            DIA      DIASEMANA         URBANA  \
# count  180219.000000  180219.000000  180219.000000  180219.000000
# mean       25.999723      15.630733       3.972334       1.019510
# std        17.756017       8.798444       1.966724       0.206587
# ...

# %%
df.describe(include=['O'])
# Out:
#             ID                      CALLE1                       CALLE2  \
# count   180219                      180212                       175938
# unique   45850                       22976                        26904
# top        413  AVENIDA EUGENIO GARZA SADA  CALZADA FRANCISCO I. MADERO
# freq        38                        1907                         1141
#
#        CARRETERA
# count       1420
# unique        25
# top
# freq        1382

# %% [markdown]
# ### Resumen
#
# **180,219 datos de 49 columnas**
# Año 2019 únicamente
#
# **Datos perdidos**:
# - CALLE1: 7
# - CALLE2: 4,281
# - CARRETERA: 178,799
#
# **Columnas destacables**:
# - TIPACCID (Tipo de accidente):
#      - 0: Certificado 0
#      - 1: Colisión con vehículo automotor
#      - 2: Colisión con peatón (atropellamiento)
#      - 3: Colisión con animal
#      - 4: Colisión con objeto fijo
#      - 5: Volcadura
#      - 6: Caída de pasajero
#      - 7: Salida del camino
#      - 8: Incendio
#      - 9: Colisión con ferrocarril
#      - 10: Colisión con motocicleta
#      - 11: Colisión con ciclista
#      - 12: Otro
# - CAUSAACCI (Causa de accidente)
#     - 1: Conductor
#     - 2: Peatón o pasajero
#     - 3: Falla de vehículo
#     - 4: Mala condición del camino
#     - 5: Otra
# - CAPAROD (Capa de rodamiento)
#     - 1: Pavimentada
#     - 2: No pavimentada
# - SEXO
#     - 1: Se fugó
#     - 2: Hombre
#     - 3: Mujer
# - ALIENTO
# - HERIDOS, MUERTOS
# - CLASE
#     - 1: Fatal
#     - 2: No fatal
#     - 3: Sólo daños

# %% [markdown]
# # Datos de CDMX

# %%
df2.head()
# Out:
#    id no_folio fecha_evento  ano_evento    mes   hora  condicion  \
# 0   0   906379   2019-01-01        2019  Enero  10:13  LESIONADO
# 1   1   906166   2019-01-01        2019  Enero   7:39  LESIONADO
# 2   2   906349   2019-01-01        2019  Enero   9:58  LESIONADO
# 3   3   906469   2019-01-01        2019  Enero  11:35  LESIONADO
# 4   4   907106   2019-01-01        2019  Enero  19:26  LESIONADO
#
#   tipo_de_evento  coordenada_x  coordenada_y  ...  identidad  \
# 0    ATROPELLADO    -99.143964     19.307892  ...     PEATON
# 1         CHOQUE    -99.136425     19.470067  ...  CONDUCTOR
# 2         CHOQUE    -99.069299     19.411029  ...  CONDUCTOR
# 3         CHOQUE    -99.124262     19.470372  ...  CONDUCTOR
# 4         CHOQUE    -98.996834     19.348251  ...  CONDUCTOR
#
#   unidad_medica_de_apoyo lugar_del_deceso trasladado_s_lesionado  \
# 0                   ERUM              NaN                    1.0
# 1                   ERUM              NaN                    0.0
# ...

# %%
df2.tail()
# Out:
#           id no_folio fecha_evento  ano_evento    mes            hora  \
# 30753  30753   567604   2018-06-29        2018  Junio  08:12:00 p. m.
# 30754  30754   567773   2018-06-29        2018  Junio  09:53:00 p. m.
# 30755  30755   566355   2018-06-29        2018  Junio  04:38:00 a. m.
# 30756  30756   567760   2018-06-29        2018  Junio  09:46:00 p. m.
# 30757  30757   567893   2018-06-29        2018  Junio  11:29:00 p. m.
#
#        condicion tipo_de_evento  coordenada_x  coordenada_y  ...  \
# 30753  LESIONADO         CHOQUE    -99.216789     19.316302  ...
# 30754  LESIONADO         CHOQUE    -99.176464     19.392405  ...
# 30755  LESIONADO      DERRAPADO    -99.144095     19.342768  ...
# 30756  LESIONADO      DERRAPADO    -99.133843     19.420006  ...
# 30757  LESIONADO      DERRAPADO    -99.097561     19.479041  ...
#
#           identidad unidad_medica_de_apoyo lugar_del_deceso  \
# 30753  MOTOCICLISTA                PM/ERUM              NaN
# ...

# %%
df2.shape
# Out:
# (30758, 62)

# %%
df2.columns
# Out:
# Index(['id', 'no_folio', 'fecha_evento', 'ano_evento', 'mes', 'hora',
#        'condicion', 'tipo_de_evento', 'coordenada_x', 'coordenada_y',
#        'punto_1', 'punto_2', 'colonia', 'alcaldia', 'tipo_de_interseccion',
#        'tipo_de_vehiculo_1', 'tipo_de_vehiculo_2', 'tipo_de_vehiculo_3',
#        'tipo_de_vehiculo_4', 'marca_de_vehiculo_1', 'marca_de_vehiculo_2',
#        'marca_de_vehiculo_3', 'marca_de_vehiculo_4', 'lesiones', 'edad_occiso',
#        'edad_lesionado', 'se_desconoce_occiso', 'se_desconoce_lesionado',
#        'rango_de_edades_menores_de_1_ano_occiso',
#        'rango_de_edades_menores_de_1_ano_lesionado', 'rango_edades_1_4_occiso',
#        'rango_edades_1_4_lesionado', 'rango_edades_5_14_occiso',
#        'rango_edades_5_14_lesionado', 'rango_edades_15_24_occiso',
#        'rango_edades_15_24_lesionado', 'rango_edades_25_34_occiso',
#        'rango_edades_25_34_lesionado', 'rango_edades_35_44_occiso',
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30758 entries, 0 to 30757
# Data columns (total 62 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   id                                          30758 non-null  int64
#  1   no_folio                                    30758 non-null  object
#  2   fecha_evento                                30758 non-null  object
#  3   ano_evento                                  30758 non-null  int64
#  4   mes                                         30758 non-null  object
#  5   hora                                        30758 non-null  object
#  6   condicion                                   30758 non-null  object
#  7   tipo_de_evento                              30758 non-null  object
#  8   coordenada_x                                30758 non-null  float64
# ...

# %%
df2.describe()
# Out:
#                  id    ano_evento  coordenada_x  coordenada_y  \
# count  30758.000000  30758.000000  30758.000000  30758.000000
# mean   15378.500000   2018.446388    -99.140562     19.392481
# std     8879.214126      0.497126      0.069885      0.067229
# min        0.000000   2018.000000    -99.999630     18.893255
# 25%     7689.250000   2018.000000    -99.175600     19.346810
# 50%    15378.500000   2018.000000    -99.141451     19.398742
# 75%    23067.750000   2019.000000    -99.105318     19.440424
# max    30757.000000   2019.000000    -98.153068     19.963880
#
#        se_desconoce_occiso  se_desconoce_lesionado  \
# count         30758.000000            30758.000000
# mean              0.005787                0.142044
# std               0.107430                0.436582
# min               0.000000                0.000000
# 25%               0.000000                0.000000
# 50%               0.000000                0.000000
# ...

# %%
df2.describe(include=['O'])
# Out:
#        no_folio fecha_evento        mes            hora  condicion  \
# count     30758        30758      30758           30758      30758
# unique    23191          730         12            2879          2
# top          SD   2018-08-18  Diciembre  08:00:00 a. m.  LESIONADO
# freq       7275           93       3510              34      30028
#
#        tipo_de_evento            punto_1            punto_2 colonia  \
# count           30758              30758              30758   30758
# unique              6               4356               6657    2253
# top            CHOQUE  ANILLO PERIFERICO  ANILLO PERIFERICO  CENTRO
# freq            15962               1215                392    1035
#
#           alcaldia  ... edad_occiso edad_lesionado     identidad  \
# count        30758  ...         808          30159         30758
# unique          16  ...         104           2619            22
# top     CUAUHTEMOC  ...          SD             SD  MOTOCICLISTA
# ...

# %% [markdown]
# ### Resumen
#
# **30,758 datos de 62 columnas**
# Años 2018 y 2019
#
# **Datos perdidos**:
# - tipo_vehiculo_2: 14,777
# - tipo_vehiculo_3: 30,096
# - tipo_vehiculo_4: 30,678
# - marca_vehiculo_1: 3
# - marca_vehiculo_2: 29,228
# - marca_vehiculo_3: 30,105
# - marca_vehiculo_4: 30,679
# - edad_occiso: 29,950
# - edad_lesionado: 599
# - lugar_del_deceso: 30,028
# - hospital: 21773
# - hora2: 8
# - observaciones: 27,918
#
# **Columnas destacables**:
# - condicion
# - tipo_de_evento
# - tipo_de_interseccion
# - lesiones
# - total_occisos
# - total_lesionados
# - identidad
# - unidad_medica_de_apoyo
# - lugar_del_deceso
# - traslado_s_lesionado
# - hospital
# - prioridad

# %% [markdown]
# ---

# %% [markdown]
# # Regresión
#
# ### 1. **Predicción del número de muertos o heridos**
#    - **Variable objetivo**: `TOTMUERTOS`, `TOTHERIDOS`, `total_occisos`, `total_lesionados`
#    - **Variables predictoras**: `HORA`, `MES`, `DIASEMANA`, `TIPACCID`, `EDAD`, `tipo_de_evento`, `coordenada_x`, `coordenada_y`
#
# En base a datos globales, se predecirá esta cantidad por día, semana o mes.
#
#
# ### 2. **Predicción de la cantidad de accidentes en una zona específica**
#    - **Variable objetivo**: Número de accidentes en una zona específica
#    - **Variables predictoras**: `coordenada_x`, `coordenada_y`, `hora`, `mes`, `dia`, `dia_semana`
#
# Se puede dividir el mapa por zonas mayormente concurridas o con mayor número de accidentes anuales y predecir cuántos accidentes ocurren en una determinada ubicación y/o momento del día.
#
#
# ### 3. **Predicción de la severidad de los accidentes**
#    - **Variable objetivo**: `lesiones` (puede transformarse en un valor numérico según gravedad)
#    - **Variables predictoras**: `tipo_de_evento`, `tipo_de_vehiculo_1`, `tipo_de_vehiculo_2`, `hora`, `coordenada_x`, `coordenada_y`, `edad_lesionado`, `condicion`
#
# Predecir la gravedad de un accidente.

# %% [markdown]
# # Clasificación
#
# ### 1. Causa/Tipo de accidente

# %% [markdown]
# # Agrupamiento
#
# ### 1. Tipo de accidente
#
# ### 2. Zona de accidente

# %% [markdown]
# ---
#
# # Data Cleaning

# %% [markdown]
# ### Dataset nacional

# %%
df[['CALLE1', 'CALLE2', 'CARRETERA', 'LATITUD', 'LONGITUD']].head()
# Out:
#                                       CALLE1                        CALLE2  \
# 0  BOULEVARD LICENCIADO ADOLFO RUÍZ CORTINES           CALLE PASEO DEL RÍO
# 1            AVENIDA PASEO DE LA SOLIDARIDAD  AVENIDA AGUASCALIENTES NORTE
# 2                        AVENIDA UNIVERSIDAD                  CALLE ABEDUL
# 3                     AVENIDA MAHATMA GANDHI        CALLE ABRAHAM GONZÁLEZ
# 4             AVENIDA GLORIETA BENITO JUÁREZ       CALLE IGNACIO T. CHÁVEZ
#
#   CARRETERA   LATITUD   LONGITUD
# 0       NaN  21.87119 -102.31962
# 1       NaN  21.91522 -102.28652
# 2       NaN  21.90032 -102.30621
# 3       NaN  21.84853 -102.29386
# 4       NaN  21.87392 -102.30055

# %%
df = df.drop('CARRETERA', axis=1)

# %%
from geopy.geocoders import Nominatim
from time import sleep
import re

calle1_lost = df[df['CALLE1'].isnull()][['LATITUD', 'LONGITUD']]

geolocator = Nominatim(user_agent="geoapi")

regex = r"([^,]+), [^,]+, Municipio de ([^,]+), ([^,]+),"
locations = []

for index, row in calle1_lost.iterrows():
    lat = row['LATITUD']
    lon = row['LONGITUD']
    
    try:
        location = geolocator.reverse((lat, lon), language="es")
        direccion = location.address if location else "No se encontró información"
        print(direccion + '\n')
        match = re.search(regex, direccion)
        if match:
            street = match.group(1).strip()
            locations.append(street)
        else:
            print(f"No se pudo procesar la dirección: {direccion}\n")
        
        sleep(1)
    except Exception as e:
        print(f"Error con las coordenadas ({lat}, {lon}): {e}")
        
locations
# Out:
# Carretera Tepames - Estapilla, El Amarradero, Municipio de Colima, Colima, 28600, México
#
# Alzada, Cerro Colorado, Municipio de Colima, Colima, 28509, México
#
# Carretera Colima - Tepames, Tepames, Municipio de Colima, Colima, 28600, México
#
# El Alpuyequito, Municipio de Colima, Colima, 28641, México
#
# No se pudo procesar la dirección: El Alpuyequito, Municipio de Colima, Colima, 28641, México
#
# Carretera al alpuyequito, El Alpuyequito, Municipio de Colima, Colima, 28641, México
#
# Carretera Tepames - Estapilla, El Amarradero, Municipio de Colima, Colima, 28600, México
#
# Carretera al alpuyequito, El Alpuyequito, Municipio de Colima, Colima, 28641, México
# ['Carretera Tepames - Estapilla',
#  'Alzada',
#  'Carretera Colima - Tepames',
#  'Carretera al alpuyequito',
#  'Carretera Tepames - Estapilla',
#  'Carretera al alpuyequito']

# %% [markdown]
# ### Dataset CDMX
